# %% [markdown]
# # Data Cleaning

# %% [markdown]
# The purpose of this notebook is to perform data cleaning on the provided dataset. This involves identifying and handling missing values, correcting inconsistent data entries, and ensuring that the dataset is prepared for further analysis.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading a DataFrame from CSV

# %%
df = pd.read_csv("unclean_data_.csv")
df
# Out:
#        Name   Age  Gender     Salary Department Date of Birth        Address  \
# 0     Rahim  25.0    Male    50000.0         HR     5/12/1995          Dhaka
# 1     Karim  30.0    Male    60000.0    Finance     9/23/1985     Chittagong
# 2     Jamal  35.0    Male    70000.0  Marketing     12/2/1975         Sylhet
# 3    Hasina   NaN  Female    80000.0    Finance     4/12/1988   78 Khulna Rd
# 4   Shabana  40.0     NaN        NaN         HR     8/14/1990        Barisal
# 5    Bashir  29.0    Male  1200000.0         HR     3/19/1982       Rajshahi
# 6     Rafiq  33.0    Male    85000.0    Finance     7/21/1989       Rajshahi
# 7       NaN  45.0  Female        NaN  Marketing     11/5/1992  -89 Sylhet Rd
# 8     Salma  22.0  Female    90000.0         HR          male          Dhaka
# 9    Moinul  55.0     NaN   300000.0    Finance      6/9/1984     Chittagong
# 10    Sadia  36.0  Female    60000.0    Finance     1/20/1993        Comilla
# 11    Nadia   NaN  Female    70000.0         HR     5/12/1995     Chittagong
# 12  Morshed  60.0    Male    25000.0  Marketing      8/3/1981        Rangpur
# 13  Taslima  42.0  Female    62000.0    Finance    10/13/1987         Khulna
# 14   Selina   NaN  Female    54000.0         HR    12/24/1976         Sylhet
# 15     Abul  38.0    Male        NaN         HR     4/12/1988         Khulna
# 16   Nasrin  31.0     NaN    68000.0    Finance     3/19/1982       Rajshahi
# 17     Asif  27.0    Male    71000.0  Marketing     7/21/1989         Sylhet
# 18    Mofiz   NaN    Male    66000.0  Marketing     8/14/1990          Dhaka
# 19    Faruk  41.0    Male        NaN         HR     9/23/1985        Barisal
#
#     Product
# 0   widgetA
# 1   WidgetB
# 2   widgetA
# 3   WidgetC
# 4   widgetb
# 5   widgetA
# 6   WidgetB
# 7   WidgetC
# 8   widgetA
# 9   widgetA
# 10  WidgetB
# 11  WidgetC
# 12  widgetb
# 13  WidgetA
# 14  WidgetC
# 15  WidgetC
# 16  widgetb
# 17  widgetC
# 18  WidgetA
# 19  WidgetA

# %% [markdown]
# ## Understanding the Dataset

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           19 non-null     str
#  1   Age            16 non-null     float64
#  2   Gender         17 non-null     str
#  3   Salary         16 non-null     float64
#  4   Department     20 non-null     str
#  5   Date of Birth  20 non-null     str
#  6   Address        20 non-null     str
#  7   Product        20 non-null     str
# dtypes: float64(2), str(6)
# memory usage: 1.4 KB

# %% [markdown]
# ## Dropping Missing Values
#
# *   This approach removes any rows or columns containing missing data.
# *   Useful when missing data is minimal and won't significantly impact the dataset.

# %%
df.isnull().sum()
# Out:
# Name             1
# Age              4
# Gender           3
# Salary           4
# Department       0
# Date of Birth    0
# Address          0
# Product          0
# dtype: int64

# %%
df_with_nulls = df[df.isnull().any(axis=1)]
df_with_nulls
# Out:
#        Name   Age  Gender    Salary Department Date of Birth        Address  \
# 3    Hasina   NaN  Female   80000.0    Finance     4/12/1988   78 Khulna Rd
# 4   Shabana  40.0     NaN       NaN         HR     8/14/1990        Barisal
# 7       NaN  45.0  Female       NaN  Marketing     11/5/1992  -89 Sylhet Rd
# 9    Moinul  55.0     NaN  300000.0    Finance      6/9/1984     Chittagong
# 11    Nadia   NaN  Female   70000.0         HR     5/12/1995     Chittagong
# 14   Selina   NaN  Female   54000.0         HR    12/24/1976         Sylhet
# 15     Abul  38.0    Male       NaN         HR     4/12/1988         Khulna
# 16   Nasrin  31.0     NaN   68000.0    Finance     3/19/1982       Rajshahi
# 18    Mofiz   NaN    Male   66000.0  Marketing     8/14/1990          Dhaka
# 19    Faruk  41.0    Male       NaN         HR     9/23/1985        Barisal
#
#     Product
# 3   WidgetC
# 4   widgetb
# 7   WidgetC
# 9   widgetA
# 11  WidgetC
# 14  WidgetC
# 15  WidgetC
# 16  widgetb
# 18  WidgetA
# 19  WidgetA

# %%
df_dropped_rows = df.dropna()   # Drop rows with any missing values
df_dropped_rows
# Out:
#        Name   Age  Gender     Salary Department Date of Birth     Address  \
# 0     Rahim  25.0    Male    50000.0         HR     5/12/1995       Dhaka
# 1     Karim  30.0    Male    60000.0    Finance     9/23/1985  Chittagong
# 2     Jamal  35.0    Male    70000.0  Marketing     12/2/1975      Sylhet
# 5    Bashir  29.0    Male  1200000.0         HR     3/19/1982    Rajshahi
# 6     Rafiq  33.0    Male    85000.0    Finance     7/21/1989    Rajshahi
# 8     Salma  22.0  Female    90000.0         HR          male       Dhaka
# 10    Sadia  36.0  Female    60000.0    Finance     1/20/1993     Comilla
# 12  Morshed  60.0    Male    25000.0  Marketing      8/3/1981     Rangpur
# 13  Taslima  42.0  Female    62000.0    Finance    10/13/1987      Khulna
# 17     Asif  27.0    Male    71000.0  Marketing     7/21/1989      Sylhet
#
#     Product
# 0   widgetA
# 1   WidgetB
# 2   widgetA
# 5   widgetA
# 6   WidgetB
# 8   widgetA
# 10  WidgetB
# 12  widgetb
# 13  WidgetA
# 17  widgetC

# %%
df_dropped_cols = df.dropna(axis=1)   # Drop columns with any missing values
df_dropped_cols
# Out:
#    Department Date of Birth        Address  Product
# 0          HR     5/12/1995          Dhaka  widgetA
# 1     Finance     9/23/1985     Chittagong  WidgetB
# 2   Marketing     12/2/1975         Sylhet  widgetA
# 3     Finance     4/12/1988   78 Khulna Rd  WidgetC
# 4          HR     8/14/1990        Barisal  widgetb
# 5          HR     3/19/1982       Rajshahi  widgetA
# 6     Finance     7/21/1989       Rajshahi  WidgetB
# 7   Marketing     11/5/1992  -89 Sylhet Rd  WidgetC
# 8          HR          male          Dhaka  widgetA
# 9     Finance      6/9/1984     Chittagong  widgetA
# 10    Finance     1/20/1993        Comilla  WidgetB
# 11         HR     5/12/1995     Chittagong  WidgetC
# 12  Marketing      8/3/1981        Rangpur  widgetb
# 13    Finance    10/13/1987         Khulna  WidgetA
# 14         HR    12/24/1976         Sylhet  WidgetC
# 15         HR     4/12/1988         Khulna  WidgetC
# 16    Finance     3/19/1982       Rajshahi  widgetb
# 17  Marketing     7/21/1989         Sylhet  widgetC
# 18  Marketing     8/14/1990          Dhaka  WidgetA
# 19         HR     9/23/1985        Barisal  WidgetA

# %% [markdown]
# # Data Imputation Techniques

# %% [markdown]
# ## Imputation with Forward/Backward Fill

# %%
new_ffill_df = df.ffill()
new_ffill_df
# Out:
#        Name   Age  Gender     Salary Department Date of Birth        Address  \
# 0     Rahim  25.0    Male    50000.0         HR     5/12/1995          Dhaka
# 1     Karim  30.0    Male    60000.0    Finance     9/23/1985     Chittagong
# 2     Jamal  35.0    Male    70000.0  Marketing     12/2/1975         Sylhet
# 3    Hasina  35.0  Female    80000.0    Finance     4/12/1988   78 Khulna Rd
# 4   Shabana  40.0  Female    80000.0         HR     8/14/1990        Barisal
# 5    Bashir  29.0    Male  1200000.0         HR     3/19/1982       Rajshahi
# 6     Rafiq  33.0    Male    85000.0    Finance     7/21/1989       Rajshahi
# 7     Rafiq  45.0  Female    85000.0  Marketing     11/5/1992  -89 Sylhet Rd
# 8     Salma  22.0  Female    90000.0         HR          male          Dhaka
# 9    Moinul  55.0  Female   300000.0    Finance      6/9/1984     Chittagong
# 10    Sadia  36.0  Female    60000.0    Finance     1/20/1993        Comilla
# 11    Nadia  36.0  Female    70000.0         HR     5/12/1995     Chittagong
# 12  Morshed  60.0    Male    25000.0  Marketing      8/3/1981        Rangpur
# 13  Taslima  42.0  Female    62000.0    Finance    10/13/1987         Khulna
# 14   Selina  42.0  Female    54000.0         HR    12/24/1976         Sylhet
# 15     Abul  38.0    Male    54000.0         HR     4/12/1988         Khulna
# 16   Nasrin  31.0    Male    68000.0    Finance     3/19/1982       Rajshahi
# 17     Asif  27.0    Male    71000.0  Marketing     7/21/1989         Sylhet
# 18    Mofiz  27.0    Male    66000.0  Marketing     8/14/1990          Dhaka
# 19    Faruk  41.0    Male    66000.0         HR     9/23/1985        Barisal
#
#     Product
# 0   widgetA
# 1   WidgetB
# 2   widgetA
# 3   WidgetC
# 4   widgetb
# 5   widgetA
# 6   WidgetB
# 7   WidgetC
# 8   widgetA
# 9   widgetA
# 10  WidgetB
# 11  WidgetC
# 12  widgetb
# 13  WidgetA
# 14  WidgetC
# 15  WidgetC
# 16  widgetb
# 17  widgetC
# 18  WidgetA
# 19  WidgetA

# %%
new_bfill_df = df.bfill()
new_bfill_df
# Out:
#        Name   Age  Gender     Salary Department Date of Birth        Address  \
# 0     Rahim  25.0    Male    50000.0         HR     5/12/1995          Dhaka
# 1     Karim  30.0    Male    60000.0    Finance     9/23/1985     Chittagong
# 2     Jamal  35.0    Male    70000.0  Marketing     12/2/1975         Sylhet
# 3    Hasina  40.0  Female    80000.0    Finance     4/12/1988   78 Khulna Rd
# 4   Shabana  40.0    Male  1200000.0         HR     8/14/1990        Barisal
# 5    Bashir  29.0    Male  1200000.0         HR     3/19/1982       Rajshahi
# 6     Rafiq  33.0    Male    85000.0    Finance     7/21/1989       Rajshahi
# 7     Salma  45.0  Female    90000.0  Marketing     11/5/1992  -89 Sylhet Rd
# 8     Salma  22.0  Female    90000.0         HR          male          Dhaka
# 9    Moinul  55.0  Female   300000.0    Finance      6/9/1984     Chittagong
# 10    Sadia  36.0  Female    60000.0    Finance     1/20/1993        Comilla
# 11    Nadia  60.0  Female    70000.0         HR     5/12/1995     Chittagong
# 12  Morshed  60.0    Male    25000.0  Marketing      8/3/1981        Rangpur
# 13  Taslima  42.0  Female    62000.0    Finance    10/13/1987         Khulna
# 14   Selina  38.0  Female    54000.0         HR    12/24/1976         Sylhet
# 15     Abul  38.0    Male    68000.0         HR     4/12/1988         Khulna
# 16   Nasrin  31.0    Male    68000.0    Finance     3/19/1982       Rajshahi
# 17     Asif  27.0    Male    71000.0  Marketing     7/21/1989         Sylhet
# 18    Mofiz  41.0    Male    66000.0  Marketing     8/14/1990          Dhaka
# 19    Faruk  41.0    Male        NaN         HR     9/23/1985        Barisal
#
#     Product
# 0   widgetA
# 1   WidgetB
# 2   widgetA
# 3   WidgetC
# 4   widgetb
# 5   widgetA
# 6   WidgetB
# 7   WidgetC
# 8   widgetA
# 9   widgetA
# 10  WidgetB
# 11  WidgetC
# 12  widgetb
# 13  WidgetA
# 14  WidgetC
# 15  WidgetC
# 16  widgetb
# 17  widgetC
# 18  WidgetA
# 19  WidgetA

# %% [markdown]
# ## Imputation with Mean, Median, or Mode
#
# *   Numerical columns can be filled with the mean or median value.
# *   Categorical columns can be filled with the mode (most frequent value).

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())
df
# Out:
#        Name   Age  Gender     Salary Department Date of Birth        Address  \
# 0     Rahim  25.0    Male    50000.0         HR     5/12/1995          Dhaka
# 1     Karim  30.0    Male    60000.0    Finance     9/23/1985     Chittagong
# 2     Jamal  35.0    Male    70000.0  Marketing     12/2/1975         Sylhet
# 3    Hasina  35.5  Female    80000.0    Finance     4/12/1988   78 Khulna Rd
# 4   Shabana  40.0     NaN        NaN         HR     8/14/1990        Barisal
# 5    Bashir  29.0    Male  1200000.0         HR     3/19/1982       Rajshahi
# 6     Rafiq  33.0    Male    85000.0    Finance     7/21/1989       Rajshahi
# 7       NaN  45.0  Female        NaN  Marketing     11/5/1992  -89 Sylhet Rd
# 8     Salma  22.0  Female    90000.0         HR          male          Dhaka
# 9    Moinul  55.0     NaN   300000.0    Finance      6/9/1984     Chittagong
# 10    Sadia  36.0  Female    60000.0    Finance     1/20/1993        Comilla
# 11    Nadia  35.5  Female    70000.0         HR     5/12/1995     Chittagong
# 12  Morshed  60.0    Male    25000.0  Marketing      8/3/1981        Rangpur
# 13  Taslima  42.0  Female    62000.0    Finance    10/13/1987         Khulna
# 14   Selina  35.5  Female    54000.0         HR    12/24/1976         Sylhet
# 15     Abul  38.0    Male        NaN         HR     4/12/1988         Khulna
# 16   Nasrin  31.0     NaN    68000.0    Finance     3/19/1982       Rajshahi
# 17     Asif  27.0    Male    71000.0  Marketing     7/21/1989         Sylhet
# 18    Mofiz  35.5    Male    66000.0  Marketing     8/14/1990          Dhaka
# 19    Faruk  41.0    Male        NaN         HR     9/23/1985        Barisal
#
#     Product
# 0   widgetA
# 1   WidgetB
# 2   widgetA
# 3   WidgetC
# 4   widgetb
# 5   widgetA
# 6   WidgetB
# 7   WidgetC
# 8   widgetA
# 9   widgetA
# 10  WidgetB
# 11  WidgetC
# 12  widgetb
# 13  WidgetA
# 14  WidgetC
# 15  WidgetC
# 16  widgetb
# 17  widgetC
# 18  WidgetA
# 19  WidgetA

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].median())
df
# Out:
#        Name   Age  Gender     Salary Department Date of Birth        Address  \
# 0     Rahim  25.0    Male    50000.0         HR     5/12/1995          Dhaka
# 1     Karim  30.0    Male    60000.0    Finance     9/23/1985     Chittagong
# 2     Jamal  35.0    Male    70000.0  Marketing     12/2/1975         Sylhet
# 3    Hasina  35.5  Female    80000.0    Finance     4/12/1988   78 Khulna Rd
# 4   Shabana  40.0     NaN    69000.0         HR     8/14/1990        Barisal
# 5    Bashir  29.0    Male  1200000.0         HR     3/19/1982       Rajshahi
# 6     Rafiq  33.0    Male    85000.0    Finance     7/21/1989       Rajshahi
# 7       NaN  45.0  Female    69000.0  Marketing     11/5/1992  -89 Sylhet Rd
# 8     Salma  22.0  Female    90000.0         HR          male          Dhaka
# 9    Moinul  55.0     NaN   300000.0    Finance      6/9/1984     Chittagong
# 10    Sadia  36.0  Female    60000.0    Finance     1/20/1993        Comilla
# 11    Nadia  35.5  Female    70000.0         HR     5/12/1995     Chittagong
# 12  Morshed  60.0    Male    25000.0  Marketing      8/3/1981        Rangpur
# 13  Taslima  42.0  Female    62000.0    Finance    10/13/1987         Khulna
# 14   Selina  35.5  Female    54000.0         HR    12/24/1976         Sylhet
# 15     Abul  38.0    Male    69000.0         HR     4/12/1988         Khulna
# 16   Nasrin  31.0     NaN    68000.0    Finance     3/19/1982       Rajshahi
# 17     Asif  27.0    Male    71000.0  Marketing     7/21/1989         Sylhet
# 18    Mofiz  35.5    Male    66000.0  Marketing     8/14/1990          Dhaka
# 19    Faruk  41.0    Male    69000.0         HR     9/23/1985        Barisal
#
#     Product
# 0   widgetA
# 1   WidgetB
# 2   widgetA
# 3   WidgetC
# 4   widgetb
# 5   widgetA
# 6   WidgetB
# 7   WidgetC
# 8   widgetA
# 9   widgetA
# 10  WidgetB
# 11  WidgetC
# 12  widgetb
# 13  WidgetA
# 14  WidgetC
# 15  WidgetC
# 16  widgetb
# 17  widgetC
# 18  WidgetA
# 19  WidgetA

# %%
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
df
# Out:
#        Name   Age  Gender     Salary Department Date of Birth        Address  \
# 0     Rahim  25.0    Male    50000.0         HR     5/12/1995          Dhaka
# 1     Karim  30.0    Male    60000.0    Finance     9/23/1985     Chittagong
# 2     Jamal  35.0    Male    70000.0  Marketing     12/2/1975         Sylhet
# 3    Hasina  35.5  Female    80000.0    Finance     4/12/1988   78 Khulna Rd
# 4   Shabana  40.0    Male    69000.0         HR     8/14/1990        Barisal
# 5    Bashir  29.0    Male  1200000.0         HR     3/19/1982       Rajshahi
# 6     Rafiq  33.0    Male    85000.0    Finance     7/21/1989       Rajshahi
# 7       NaN  45.0  Female    69000.0  Marketing     11/5/1992  -89 Sylhet Rd
# 8     Salma  22.0  Female    90000.0         HR          male          Dhaka
# 9    Moinul  55.0    Male   300000.0    Finance      6/9/1984     Chittagong
# 10    Sadia  36.0  Female    60000.0    Finance     1/20/1993        Comilla
# 11    Nadia  35.5  Female    70000.0         HR     5/12/1995     Chittagong
# 12  Morshed  60.0    Male    25000.0  Marketing      8/3/1981        Rangpur
# 13  Taslima  42.0  Female    62000.0    Finance    10/13/1987         Khulna
# 14   Selina  35.5  Female    54000.0         HR    12/24/1976         Sylhet
# 15     Abul  38.0    Male    69000.0         HR     4/12/1988         Khulna
# 16   Nasrin  31.0    Male    68000.0    Finance     3/19/1982       Rajshahi
# 17     Asif  27.0    Male    71000.0  Marketing     7/21/1989         Sylhet
# 18    Mofiz  35.5    Male    66000.0  Marketing     8/14/1990          Dhaka
# 19    Faruk  41.0    Male    69000.0         HR     9/23/1985        Barisal
#
#     Product
# 0   widgetA
# 1   WidgetB
# 2   widgetA
# 3   WidgetC
# 4   widgetb
# 5   widgetA
# 6   WidgetB
# 7   WidgetC
# 8   widgetA
# 9   widgetA
# 10  WidgetB
# 11  WidgetC
# 12  widgetb
# 13  WidgetA
# 14  WidgetC
# 15  WidgetC
# 16  widgetb
# 17  widgetC
# 18  WidgetA
# 19  WidgetA

# %% [markdown]
# ## Standardizing string column

# %%
df["Product"] = df["Product"].str.lower()
df
# Out:
#        Name   Age  Gender     Salary Department Date of Birth        Address  \
# 0     Rahim  25.0    Male    50000.0         HR     5/12/1995          Dhaka
# 1     Karim  30.0    Male    60000.0    Finance     9/23/1985     Chittagong
# 2     Jamal  35.0    Male    70000.0  Marketing     12/2/1975         Sylhet
# 3    Hasina  35.5  Female    80000.0    Finance     4/12/1988   78 Khulna Rd
# 4   Shabana  40.0    Male    69000.0         HR     8/14/1990        Barisal
# 5    Bashir  29.0    Male  1200000.0         HR     3/19/1982       Rajshahi
# 6     Rafiq  33.0    Male    85000.0    Finance     7/21/1989       Rajshahi
# 7       NaN  45.0  Female    69000.0  Marketing     11/5/1992  -89 Sylhet Rd
# 8     Salma  22.0  Female    90000.0         HR          male          Dhaka
# 9    Moinul  55.0    Male   300000.0    Finance      6/9/1984     Chittagong
# 10    Sadia  36.0  Female    60000.0    Finance     1/20/1993        Comilla
# 11    Nadia  35.5  Female    70000.0         HR     5/12/1995     Chittagong
# 12  Morshed  60.0    Male    25000.0  Marketing      8/3/1981        Rangpur
# 13  Taslima  42.0  Female    62000.0    Finance    10/13/1987         Khulna
# 14   Selina  35.5  Female    54000.0         HR    12/24/1976         Sylhet
# 15     Abul  38.0    Male    69000.0         HR     4/12/1988         Khulna
# 16   Nasrin  31.0    Male    68000.0    Finance     3/19/1982       Rajshahi
# 17     Asif  27.0    Male    71000.0  Marketing     7/21/1989         Sylhet
# 18    Mofiz  35.5    Male    66000.0  Marketing     8/14/1990          Dhaka
# 19    Faruk  41.0    Male    69000.0         HR     9/23/1985        Barisal
#
#     Product
# 0   widgeta
# 1   widgetb
# 2   widgeta
# 3   widgetc
# 4   widgetb
# 5   widgeta
# 6   widgetb
# 7   widgetc
# 8   widgeta
# 9   widgeta
# 10  widgetb
# 11  widgetc
# 12  widgetb
# 13  widgeta
# 14  widgetc
# 15  widgetc
# 16  widgetb
# 17  widgetc
# 18  widgeta
# 19  widgeta

# %% [markdown]
# ## Dropping any duplicate rows

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#        Name   Age  Gender     Salary Department Date of Birth        Address  \
# 0     Rahim  25.0    Male    50000.0         HR     5/12/1995          Dhaka
# 1     Karim  30.0    Male    60000.0    Finance     9/23/1985     Chittagong
# 2     Jamal  35.0    Male    70000.0  Marketing     12/2/1975         Sylhet
# 3    Hasina  35.5  Female    80000.0    Finance     4/12/1988   78 Khulna Rd
# 4   Shabana  40.0    Male    69000.0         HR     8/14/1990        Barisal
# 5    Bashir  29.0    Male  1200000.0         HR     3/19/1982       Rajshahi
# 6     Rafiq  33.0    Male    85000.0    Finance     7/21/1989       Rajshahi
# 7       NaN  45.0  Female    69000.0  Marketing     11/5/1992  -89 Sylhet Rd
# 8     Salma  22.0  Female    90000.0         HR          male          Dhaka
# 9    Moinul  55.0    Male   300000.0    Finance      6/9/1984     Chittagong
# 10    Sadia  36.0  Female    60000.0    Finance     1/20/1993        Comilla
# 11    Nadia  35.5  Female    70000.0         HR     5/12/1995     Chittagong
# 12  Morshed  60.0    Male    25000.0  Marketing      8/3/1981        Rangpur
# 13  Taslima  42.0  Female    62000.0    Finance    10/13/1987         Khulna
# 14   Selina  35.5  Female    54000.0         HR    12/24/1976         Sylhet
# 15     Abul  38.0    Male    69000.0         HR     4/12/1988         Khulna
# 16   Nasrin  31.0    Male    68000.0    Finance     3/19/1982       Rajshahi
# 17     Asif  27.0    Male    71000.0  Marketing     7/21/1989         Sylhet
# 18    Mofiz  35.5    Male    66000.0  Marketing     8/14/1990          Dhaka
# 19    Faruk  41.0    Male    69000.0         HR     9/23/1985        Barisal
#
#     Product
# 0   widgeta
# 1   widgetb
# 2   widgeta
# 3   widgetc
# 4   widgetb
# 5   widgeta
# 6   widgetb
# 7   widgetc
# 8   widgeta
# 9   widgeta
# 10  widgetb
# 11  widgetc
# 12  widgetb
# 13  widgeta
# 14  widgetc
# 15  widgetc
# 16  widgetb
# 17  widgetc
# 18  widgeta
# 19  widgeta

# %% [markdown]
# If you attempt to convert a column to datetime format, but there is an invalid entry like "male" in the Date of Birth column, you can handle this issue by using the errors='coerce' argument with pd.to_datetime(). This will convert any invalid values (like "male") to NaT (Not a Time), which allows you to easily identify and handle them.

# %%
df["Date of Birth"] = pd.to_datetime(df["Date of Birth"], errors='coerce')
df
# Out:
#        Name   Age  Gender     Salary Department Date of Birth        Address  \
# 0     Rahim  25.0    Male    50000.0         HR    1995-05-12          Dhaka
# 1     Karim  30.0    Male    60000.0    Finance    1985-09-23     Chittagong
# 2     Jamal  35.0    Male    70000.0  Marketing    1975-12-02         Sylhet
# 3    Hasina  35.5  Female    80000.0    Finance    1988-04-12   78 Khulna Rd
# 4   Shabana  40.0    Male    69000.0         HR    1990-08-14        Barisal
# 5    Bashir  29.0    Male  1200000.0         HR    1982-03-19       Rajshahi
# 6     Rafiq  33.0    Male    85000.0    Finance    1989-07-21       Rajshahi
# 7       NaN  45.0  Female    69000.0  Marketing    1992-11-05  -89 Sylhet Rd
# 8     Salma  22.0  Female    90000.0         HR           NaT          Dhaka
# 9    Moinul  55.0    Male   300000.0    Finance    1984-06-09     Chittagong
# 10    Sadia  36.0  Female    60000.0    Finance    1993-01-20        Comilla
# 11    Nadia  35.5  Female    70000.0         HR    1995-05-12     Chittagong
# 12  Morshed  60.0    Male    25000.0  Marketing    1981-08-03        Rangpur
# 13  Taslima  42.0  Female    62000.0    Finance    1987-10-13         Khulna
# 14   Selina  35.5  Female    54000.0         HR    1976-12-24         Sylhet
# 15     Abul  38.0    Male    69000.0         HR    1988-04-12         Khulna
# 16   Nasrin  31.0    Male    68000.0    Finance    1982-03-19       Rajshahi
# 17     Asif  27.0    Male    71000.0  Marketing    1989-07-21         Sylhet
# 18    Mofiz  35.5    Male    66000.0  Marketing    1990-08-14          Dhaka
# 19    Faruk  41.0    Male    69000.0         HR    1985-09-23        Barisal
#
#     Product
# 0   widgeta
# 1   widgetb
# 2   widgeta
# 3   widgetc
# 4   widgetb
# 5   widgeta
# 6   widgetb
# 7   widgetc
# 8   widgeta
# 9   widgeta
# 10  widgetb
# 11  widgetc
# 12  widgetb
# 13  widgeta
# 14  widgetc
# 15  widgetc
# 16  widgetb
# 17  widgetc
# 18  widgeta
# 19  widgeta

# %% [markdown]
# # Data Cleaning 2

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes

diabetes = load_diabetes()

df = pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names)

# %%
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# 1   -0.039493 -0.068332 -0.092204
# 2   -0.002592  0.002861 -0.025930
# 3    0.034309  0.022688 -0.009362
# 4   -0.002592 -0.031988 -0.046641
# ..        ...       ...       ...
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064
#
# [442 rows x 10 columns]

# %% [markdown]
# ## Finding Outliers

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=df['bmi'])

plt.title("Boxplot of BMI")
plt.show()

# %%
removed_outliers = df[df['bmi'] <= 0.12]

plt.figure(figsize=(8,6))
sns.boxplot(x=removed_outliers['bmi'])
plt.title("Boxplot with Outliers Removed")
plt.show()

# %% [markdown]
# ### Z-Scores

# %%
# 68% of values lie within 1 standard deviation of the mean (Z-score between -1 and 1).
# 95% of values lie within 2 standard deviations of the mean (Z-score between -2 and 2).
# 99.7% of values lie within 3 standard deviations of the mean (Z-score between -3 and 3).

from scipy.stats import zscore

bmi_zscore = zscore(df['bmi'])
bmi_zscore

# %%
z_threshold = 2

bmi_zscore = np.abs(bmi_zscore)

outlier_indices = np.where(bmi_zscore > z_threshold)
outlier_indices[0]
# Out:
# array([ 32, 114, 130, 138, 145, 251, 256, 262, 327, 332, 362, 366, 367,
#        403, 405])

# %%
removed_indices = df.drop(outlier_indices[0])

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=removed_indices['bmi'])
plt.title("Boxplot with Outliers Removed")
plt.show()
