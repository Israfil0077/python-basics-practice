# %% [markdown]
# First Python Program

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %% [markdown]
# Python Comments:
#
#
# 1.   Single Line Comment
# 2.   Multi-line Comment

# %%
#single line comment
#Multiple line comment
#Multiple line comment
"""
This is a multi-line comment
or docstring in Python
"""
print('Single & Multi-line comments')
# Out:
# Single & Multi-line comments

# %% [markdown]
# **Variables**

# %%
## Creating Variables ##
# Python has no command for declaring a variable.
# A variable is created the moment you first assign a value to it.
x = 5
y = "Hello, World!"
name = "Israfil"
print(x)
print(y)
print(name)
pi = 3.14159
print(pi)
# Out:
# 5
# Hello, World!
# Israfil
# 3.14159

# %%
# Python variables don't require a fixed type and can change type anytime.
x= 10
x= "Now I'm a string"
print(x)
# Out:
# Now I'm a string
# Now I'm a string

# %%
# Casting
#common type casting Functions
int() #cnvert to integer
float() #convert to float
str() #convert to string
bool() #convert to boolean

x='10'
y=int(x)
z=float(x)
print(y,z)

a=100
b=str(a)
print(b)

print(bool(0)) #False
print(bool(1)) #True
print(bool("")) #False
print(bool("Hello")) #True
# Out:
# 10 10.0
# 100
# False
# True
# False
# True

# %%
#Not everything can be converted

x= "hello"
y=int(x) # Error!!!!
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 4
#       1 #Not everything can be converted
#       3 x= "hello"
# ----> 4 y=int(x) # Erroe!!!!
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
# Real Example of type conversion
age = input("Enter your age: ") #input() returns a string
age = int(age) #convert string to integer
print("Three years ago your age was :" + str(age - 3))  # 3 years ago
# Out:
# Three years ago your age was :19

# %%
# Get the type
x=10
y="Israfil"
z=[12, 23, 56]

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'list'>

# %%
# Single or Double Quotes?

msg = "I'm learning Python " # Using double quotes to avoid conflict with the apostrophe in "I'm"
print(msg)
msg2 = 'She said, "Python is great!"' # Using single quotes to avoid conflict with the double quotes in the string
print(msg2)

# %% [markdown]
# **Variables**
#
# **Rules for Python variables:**
#
# *   A variable name must start with a letter or the underscore character
# *   A variable name cannot start with a number
# *   A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# *   Variable names are case-sensitive (age, Age and AGE are three different variables)
# *   A variable name cannot be any of the Python keywords.
#
#
#
#
# Python has no command for declaring a variable.
# A variable is created the moment you first assign a value to it

# %%
## Multi Words Variable Names ##

# There are several techniques you can use to make them more readable:
#1 Camel Case - Each word, except the first, starts with capital letter [myVariableName = "John"]
#2 Pascal Case - Each word starts with a capital letter [MyVariableName = "John"]
#3 Snake Case - Each word is separated by an underscore character [my_variable_name = "John"]

# %%
## Assign multiple values ##

#1 Many values to Multiple variables

#Note: Make sure the number of variables matches the number of values, or else you will get an error.


#2 One value to multiple variables

# %%
## Unpack a Collection

# If you have a collection of values in a list, tuple, etc. Python allows you to extract the vlaues into variables. This is called unpacking.

# %% [markdown]
# **Output Variables**

# %%
#1

#2

#3

#4

#5

#6

#7

#Note: In the print() function, when you try to combine a string and a number with + operator, Python will give you an error

#8

# %% [markdown]
# **Python Data Types**
#
# In Python, the data type is set when you assign a value to a variable:
#
# ![Screenshot 2025-07-23 055843.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What does mutable mean?**
#
# means you can, add, or remove elements from a list without creating a new list

# %%
# List -> Mutable

# %%
# tuple -> immutable

# %%
# Dictionary

# %%
# Set

# %% [markdown]
# **Python Numbers**
#
# There are three numeric types in Python:
#
# 1.   int
# 2.   float
# 3.   complex

# %%
# Float can also be scientific numbers with an "e" to indicate the power of 10

# %% [markdown]
# **Random Number**

# %% [markdown]
# **Python String**
#
# Strings in python are surrounded by either single quotation marks, or double quotation marks

# %%
# Quotes inside quotes
# you can use quotes inside a string, as long as they don't match the quotes surrounding the string

# %% [markdown]
# **Python If...Else**

# %%
## Python Indentation ##

# %% [markdown]
# **Operators**

# %%
# And Operator

# %%
# Or Operator

# %%
# Not Operator

# %%
# Nested If

# %% [markdown]
# Loops:
#
#
# *   while
# *   for
