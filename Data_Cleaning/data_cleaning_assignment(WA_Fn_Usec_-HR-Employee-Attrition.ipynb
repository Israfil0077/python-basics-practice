# %% [markdown]
# # Assignment-2

# %% [markdown]
# ### Required Tasks

# %% [markdown]
# a. Understanding the dataset:
# 1. Import the dataset in a notebook environment with python pandas.
# 2. Show the number of attributes (columns) and number of records (rows).
# 3. Show the statistics of the dataset (column wise mean, standard deviation,
# max, min etc.).
# 4. Count the number of missing values in the dataset and show them.
# 5. Count the number of duplicate values in the dataset and show them.

# %%
#a. 1. Import the dataset in a notebook environment with python pandas
import pandas as pd
import numpy as np

df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#a.2. Show the number of attributes (columns) and number of records (rows)
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#a.3. Show the statistics of the dataset (column wise mean, standard deviation,max, min etc.).
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#a.4. Count the number of missing values in the dataset and show them.
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#a.5. Count the number of duplicate values in the dataset and show them.
df.duplicated().sum()
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# b. Data Cleaning:
# 1. If you find any missing values in the dataset (nan values) replace those with
# the column-wise median for numeric data, and with mode for categorical
# data.
# 2. If you find any duplicates in the dataset, keep just one copy of the data.
# 3. Remember, if any row in the target column (Attrition) is missing, you must
# drop that row.
# 4. Remove any outliers present in the numeric columns.
# 5. Standardize the string columns data to lower case.

# %%
#b.3 Remember, if any row in the target column (Attrition) is missing, you must drop that row.

#this is done first to ensure that we do not lose any data that could be useful for analysis,
# as the target variable is crucial for any predictive modeling tasks. By dropping rows with 
# missing values in the 'Attrition' column, we can maintain the integrity of our dataset and 
# ensure that our analysis is based on complete and accurate information.

df.dropna(subset=['Attrition'], inplace=True) # Drop rows where 'Attrition' is missing
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#b. 1. If you find any missing values in the dataset (nan values) replace those with
#the column-wise median for numeric data, and with mode for categorical
#data.

numeric_cols = df.select_dtypes(include=[np.number]).columns # Select numeric columns
categorical_cols = df.select_dtypes(include=['object']).columns # Select categorical columns

# %%
# Fill missing values in numeric columns with median
for col in numeric_cols:
    df[col]= df[col].fillna(df[col].median())
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
# Fill missing values in categorical columns with mode
for col in categorical_cols:  
    df[col] = df[col].fillna(df[col].mode()[0])
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#b.2. If you find any duplicates in the dataset, keep just one copy of the data.
df = df.drop_duplicates()
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#b.4. Remove any outliers present in the numeric columns.
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore

# %%
#finding outliers using boxplot
for col in numeric_cols:

    plt.figure(figsize=(12,6))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
z_threshold = 3

# Only use columns that have more than one unique value
varying_cols = [col for col in numeric_cols if df[col].nunique() > 1]

z_scores = np.abs(zscore(df[varying_cols]))
outlier_mask = (z_scores < z_threshold).all(axis=1)

df = df[outlier_mask]
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#finding outliers using boxplot after removing outliers
for col in numeric_cols:
    plt.figure(figsize=(12,6))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
#b.5. Standardize the string columns data to lower case.
for col in categorical_cols:
    df[col] = df[col].str.lower()
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2136\43747187.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].str.lower()
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       yes      travel_rarely       1102                   sales
# 1      49        no  travel_frequently        279  research & development
# 2      37       yes      travel_rarely       1373  research & development
# 3      33        no  travel_frequently       1392  research & development
# 4      27        no      travel_rarely        591  research & development
# ...   ...       ...                ...        ...                     ...
# ...

# %% [markdown]
# c. Creation of Input and Output Features:
# 1. You need to split the data into two parts. The “Features” variable will consist
# of all the columns in the dataset except the target column. And the “Labels”
# variable will contain only the target column. This way, you can prepare the
# dataset for any machine learning model.
# 2. The target column contains two classes (Yes/No). Convert them to numeric
# classes: 0 (No) and 1 (Yes) and replace them in the “Labels” column. This

# %%
# c.1. You need to split the data into two parts. The “Features” variable will consist
#of all the columns in the dataset except the target column. And the “Labels”
#variable will contain only the target column. This way, you can prepare the
#dataset for any machine learning model.
Features = df.drop(['Attrition'], axis=1)  # Features (all columns except 'Attrition')
Features
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      41      travel_rarely       1102                   sales
# 1      49  travel_frequently        279  research & development
# 2      37      travel_rarely       1373  research & development
# 3      33  travel_frequently       1392  research & development
# 4      27      travel_rarely        591  research & development
# ...   ...                ...        ...                     ...
# 1465   36  travel_frequently        884  research & development
# 1466   39      travel_rarely        613  research & development
# 1467   27      travel_rarely        155  research & development
# 1468   49  travel_frequently       1023                   sales
# 1469   34      travel_rarely        628  research & development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  life sciences              1
# 1                    8          1  life sciences              1
# ...

# %%
Labels = df['Attrition']  # Labels (only the 'Attrition' column)
Labels
# Out:
# 0       yes
# 1        no
# 2       yes
# 3        no
# 4        no
#        ...
# 1465     no
# 1466     no
# 1467     no
# 1468     no
# 1469     no
# Name: Attrition, Length: 1387, dtype: object

# %%
Labels= Labels.map({'yes': 1, 'no': 0})
Labels
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1387, dtype: int64

# %%
df = pd.concat([Features, Labels], axis=1) # Combine Features and Labels back into a single DataFrame
df
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      41      travel_rarely       1102                   sales
# 1      49  travel_frequently        279  research & development
# 2      37      travel_rarely       1373  research & development
# 3      33  travel_frequently       1392  research & development
# 4      27      travel_rarely        591  research & development
# ...   ...                ...        ...                     ...
# 1465   36  travel_frequently        884  research & development
# 1466   39      travel_rarely        613  research & development
# 1467   27      travel_rarely        155  research & development
# 1468   49  travel_frequently       1023                   sales
# 1469   34      travel_rarely        628  research & development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  life sciences              1
# 1                    8          1  life sciences              1
# ...
